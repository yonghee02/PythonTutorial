# %%
from IPython.display import Image

# %%
import math

# %%
Image("img/01_pb.png")

# %%
# func(radian)
# cotangent = 1/tan
answer = math.sin(math.radians(70)
                 + math.tan(math.radians(100))
                 + math.cos(math.radians(160))
                 + (1/math.tan(math.radians(190))))

# %%
answer
# Out:
# 0.27831356559281667

# %%
Image("img/02_pb.png")

# %%
# write your answer
